# %%
from pymongo import MongoClient
from pprint import pprint

# %%
from pymongo import MongoClient
# pprint library is used to make the output look more pretty
from pprint import pprint
# connect to MongoDB, change the << MONGODB URL >> to reflect your own connection string
client = MongoClient(port=27017)
db = client.admin
# Issue the serverStatus command and print the results
serverStatusResult=db.command("serverStatus")
pprint(serverStatusResult)
# Out:
# {'asserts': {'msg': 0, 'regular': 0, 'rollovers': 0, 'user': 11, 'warning': 0},
#  'connections': {'active': 1,
#                  'available': 999998,
#                  'current': 2,
#                  'totalCreated': 2},
#  'electionMetrics': {'averageCatchUpOps': 0.0,
#                      'catchUpTakeover': {'called': 0, 'successful': 0},
#                      'electionTimeout': {'called': 0, 'successful': 0},
#                      'freezeTimeout': {'called': 0, 'successful': 0},
#                      'numCatchUps': 0,
#                      'numCatchUpsAlreadyCaughtUp': 0,
#                      'numCatchUpsFailedWithError': 0,
#                      'numCatchUpsFailedWithNewTerm': 0,
#                      'numCatchUpsFailedWithReplSetAbortPrimaryCatchUpCmd': 0,
#                      'numCatchUpsSkipped': 0,
#                      'numCatchUpsSucceeded': 0,
#                      'numCatchUpsTimedOut': 0,
#                      'numStepDownsCausedByHigherTerm': 0,
#                      'priorityTakeover': {'called': 0, 'successful': 0},
#                      'stepUpCmd': {'called': 0, 'successful': 0}},
#  'extra_info': {'availPageFileMB': 2737,
#                 'note': 'fields vary by platform',
#                 'page_faults': 57367,
#                 'ramMB': 8003,
#                 'totalPageFileMB': 9091,
#                 'usagePageFileMB': 186},
#  'flowControl': {'enabled': True,
#                  'isLagged': False,
#                  'isLaggedCount': 0,
#                  'isLaggedTimeMicros': 0,
#                  'locksPerOp': 0.0,
#                  'sustainerRate': 0,
#                  'targetRateLimit': 1000000000,
#                  'timeAcquiringMicros': 8},
#  'freeMonitoring': {'state': 'undecided'},
#  'globalLock': {'activeClients': {'readers': 0, 'total': 0, 'writers': 0},
#                 'currentQueue': {'readers': 0, 'total': 0, 'writers': 0},
#                 'totalTime': 381152000},
#  'host': 'die_zer0-PC',
#  'localTime': datetime.datetime(2020, 2, 23, 5, 34, 47, 759000),
#  'locks': {'Collection': {'acquireCount': {'R': 1, 'W': 2, 'r': 410, 'w': 8}},
#            'Database': {'acquireCount': {'W': 6, 'r': 401, 'w': 8}},
#            'Global': {'acquireCount': {'W': 4, 'r': 1157, 'w': 13}},
#            'Mutex': {'acquireCount': {'r': 412}},
#            'ParallelBatchWriterMode': {'acquireCount': {'r': 26}},
#            'ReplicationStateTransition': {'acquireCount': {'w': 1174}},
#            'oplog': {'acquireCount': {'r': 377}}},
#  'logicalSessionRecordCache': {'activeSessionsCount': 1,
#                                'lastSessionsCollectionJobCursorsClosed': 0,
#                                'lastSessionsCollectionJobDurationMillis': 0,
#                                'lastSessionsCollectionJobEntriesEnded': 0,
#                                'lastSessionsCollectionJobEntriesRefreshed': 0,
#                                'lastSessionsCollectionJobTimestamp': datetime.datetime(2020, 2, 23, 5, 33, 28, 191000),
#                                'lastTransactionReaperJobDurationMillis': 0,
#                                'lastTransactionReaperJobEntriesCleanedUp': 0,
#                                'lastTransactionReaperJobTimestamp': datetime.datetime(2020, 2, 23, 5, 33, 28, 192000),
#                                'sessionCatalogSize': 0,
#                                'sessionsCollectionJobCount': 2,
#                                'transactionReaperJobCount': 2},
#  'mem': {'bits': 64, 'resident': 159, 'supported': True, 'virtual': 1398},
#  'metrics': {'commands': {'<UNKNOWN>': 0,
#                           '_addShard': {'failed': 0, 'total': 0},
#                           '_cloneCatalogData': {'failed': 0, 'total': 0},
#                           '_cloneCollectionOptionsFromPrimaryShard': {'failed': 0,
#                                                                       'total': 0},
#                           '_configsvrAddShard': {'failed': 0, 'total': 0},
#                           '_configsvrAddShardToZone': {'failed': 0, 'total': 0},
#                           '_configsvrBalancerStart': {'failed': 0, 'total': 0},
#                           '_configsvrBalancerStatus': {'failed': 0, 'total': 0},
#                           '_configsvrBalancerStop': {'failed': 0, 'total': 0},
#                           '_configsvrClearJumboFlag': {'failed': 0, 'total': 0},
#                           '_configsvrCommitChunkMerge': {'failed': 0,
#                                                          'total': 0},
#                           '_configsvrCommitChunkMigration': {'failed': 0,
#                                                              'total': 0},
#                           '_configsvrCommitChunkSplit': {'failed': 0,
#                                                          'total': 0},
#                           '_configsvrCommitMovePrimary': {'failed': 0,
#                                                           'total': 0},
#                           '_configsvrCreateCollection': {'failed': 0,
#                                                          'total': 0},
#                           '_configsvrCreateDatabase': {'failed': 0, 'total': 0},
#                           '_configsvrDropCollection': {'failed': 0, 'total': 0},
#                           '_configsvrDropDatabase': {'failed': 0, 'total': 0},
#                           '_configsvrEnableSharding': {'failed': 0, 'total': 0},
#                           '_configsvrMoveChunk': {'failed': 0, 'total': 0},
#                           '_configsvrMovePrimary': {'failed': 0, 'total': 0},
#                           '_configsvrRemoveShard': {'failed': 0, 'total': 0},
#                           '_configsvrRemoveShardFromZone': {'failed': 0,
#                                                             'total': 0},
#                           '_configsvrShardCollection': {'failed': 0,
#                                                         'total': 0},
#                           '_configsvrUpdateZoneKeyRange': {'failed': 0,
#                                                            'total': 0},
#                           '_flushDatabaseCacheUpdates': {'failed': 0,
#                                                          'total': 0},
#                           '_flushRoutingTableCacheUpdates': {'failed': 0,
#                                                              'total': 0},
#                           '_getNextSessionMods': {'failed': 0, 'total': 0},
#                           '_getUserCacheGeneration': {'failed': 0, 'total': 0},
#                           '_isSelf': {'failed': 0, 'total': 0},
#                           '_mergeAuthzCollections': {'failed': 0, 'total': 0},
#                           '_migrateClone': {'failed': 0, 'total': 0},
#                           '_movePrimary': {'failed': 0, 'total': 0},
#                           '_recvChunkAbort': {'failed': 0, 'total': 0},
#                           '_recvChunkCommit': {'failed': 0, 'total': 0},
#                           '_recvChunkStart': {'failed': 0, 'total': 0},
#                           '_recvChunkStatus': {'failed': 0, 'total': 0},
#                           '_shardsvrShardCollection': {'failed': 0, 'total': 0},
#                           '_transferMods': {'failed': 0, 'total': 0},
#                           'abortTransaction': {'failed': 0, 'total': 0},
#                           'aggregate': {'failed': 0, 'total': 0},
#                           'appendOplogNote': {'failed': 0, 'total': 0},
#                           'applyOps': {'failed': 0, 'total': 0},
#                           'authenticate': {'failed': 0, 'total': 0},
#                           'availableQueryOptions': {'failed': 0, 'total': 0},
#                           'buildInfo': {'failed': 0, 'total': 0},
#                           'checkShardingIndex': {'failed': 0, 'total': 0},
#                           'cleanupOrphaned': {'failed': 0, 'total': 0},
#                           'cloneCollection': {'failed': 0, 'total': 0},
#                           'cloneCollectionAsCapped': {'failed': 0, 'total': 0},
#                           'collMod': {'failed': 0, 'total': 0},
#                           'collStats': {'failed': 0, 'total': 0},
#                           'commitTransaction': {'failed': 0, 'total': 0},
#                           'compact': {'failed': 0, 'total': 0},
#                           'connPoolStats': {'failed': 0, 'total': 0},
#                           'connPoolSync': {'failed': 0, 'total': 0},
#                           'connectionStatus': {'failed': 0, 'total': 0},
#                           'convertToCapped': {'failed': 0, 'total': 0},
#                           'coordinateCommitTransaction': {'failed': 0,
#                                                           'total': 0},
#                           'count': {'failed': 0, 'total': 0},
#                           'create': {'failed': 0, 'total': 0},
#                           'createIndexes': {'failed': 0, 'total': 1},
#                           'createRole': {'failed': 0, 'total': 0},
#                           'createUser': {'failed': 0, 'total': 0},
#                           'currentOp': {'failed': 0, 'total': 0},
#                           'dataSize': {'failed': 0, 'total': 0},
#                           'dbHash': {'failed': 0, 'total': 0},
#                           'dbStats': {'failed': 0, 'total': 0},
#                           'delete': {'failed': 0, 'total': 0},
#                           'distinct': {'failed': 0, 'total': 0},
#                           'driverOIDTest': {'failed': 0, 'total': 0},
#                           'drop': {'failed': 0, 'total': 0},
#                           'dropAllRolesFromDatabase': {'failed': 0, 'total': 0},
#                           'dropAllUsersFromDatabase': {'failed': 0, 'total': 0},
#                           'dropConnections': {'failed': 0, 'total': 0},
#                           'dropDatabase': {'failed': 0, 'total': 0},
#                           'dropIndexes': {'failed': 0, 'total': 0},
#                           'dropRole': {'failed': 0, 'total': 0},
#                           'dropUser': {'failed': 0, 'total': 0},
#                           'endSessions': {'failed': 0, 'total': 0},
#                           'explain': {'failed': 0, 'total': 0},
#                           'features': {'failed': 0, 'total': 0},
#                           'filemd5': {'failed': 0, 'total': 0},
#                           'find': {'failed': 0, 'total': 2},
#                           'findAndModify': {'failed': 0, 'total': 0},
#                           'flushRouterConfig': {'failed': 0, 'total': 0},
#                           'fsync': {'failed': 0, 'total': 0},
#                           'fsyncUnlock': {'failed': 0, 'total': 0},
#                           'geoSearch': {'failed': 0, 'total': 0},
#                           'getCmdLineOpts': {'failed': 0, 'total': 0},
#                           'getDatabaseVersion': {'failed': 0, 'total': 0},
#                           'getDiagnosticData': {'failed': 0, 'total': 0},
#                           'getFreeMonitoringStatus': {'failed': 0, 'total': 0},
#                           'getLastError': {'failed': 0, 'total': 0},
#                           'getLog': {'failed': 0, 'total': 0},
#                           'getMore': {'failed': 0, 'total': 0},
#                           'getParameter': {'failed': 0, 'total': 0},
#                           'getShardMap': {'failed': 0, 'total': 0},
#                           'getShardVersion': {'failed': 0, 'total': 0},
#                           'getnonce': {'failed': 0, 'total': 0},
#                           'grantPrivilegesToRole': {'failed': 0, 'total': 0},
#                           'grantRolesToRole': {'failed': 0, 'total': 0},
#                           'grantRolesToUser': {'failed': 0, 'total': 0},
#                           'hostInfo': {'failed': 0, 'total': 0},
#                           'insert': {'failed': 0, 'total': 0},
#                           'invalidateUserCache': {'failed': 0, 'total': 0},
#                           'isMaster': {'failed': 0, 'total': 2},
#                           'killAllSessions': {'failed': 0, 'total': 0},
#                           'killAllSessionsByPattern': {'failed': 0, 'total': 0},
#                           'killCursors': {'failed': 0, 'total': 0},
#                           'killOp': {'failed': 0, 'total': 0},
#                           'killSessions': {'failed': 0, 'total': 0},
#                           'listCollections': {'failed': 0, 'total': 0},
#                           'listCommands': {'failed': 0, 'total': 0},
#                           'listDatabases': {'failed': 0, 'total': 0},
#                           'listIndexes': {'failed': 2, 'total': 4},
#                           'lockInfo': {'failed': 0, 'total': 0},
#                           'logRotate': {'failed': 0, 'total': 0},
#                           'logout': {'failed': 0, 'total': 0},
#                           'mapReduce': {'failed': 0, 'total': 0},
#                           'mapreduce': {'shardedfinish': {'failed': 0,
#                                                           'total': 0}},
#                           'mergeChunks': {'failed': 0, 'total': 0},
#                           'moveChunk': {'failed': 0, 'total': 0},
#                           'ping': {'failed': 0, 'total': 0},
#                           'planCacheClear': {'failed': 0, 'total': 0},
#                           'planCacheClearFilters': {'failed': 0, 'total': 0},
#                           'planCacheListFilters': {'failed': 0, 'total': 0},
#                           'planCacheListPlans': {'failed': 0, 'total': 0},
#                           'planCacheListQueryShapes': {'failed': 0, 'total': 0},
#                           'planCacheSetFilter': {'failed': 0, 'total': 0},
#                           'prepareTransaction': {'failed': 0, 'total': 0},
#                           'profile': {'failed': 0, 'total': 0},
#                           'reIndex': {'failed': 0, 'total': 0},
#                           'refreshSessions': {'failed': 0, 'total': 0},
#                           'renameCollection': {'failed': 0, 'total': 0},
#                           'repairCursor': {'failed': 0, 'total': 0},
#                           'repairDatabase': {'failed': 0, 'total': 0},
#                           'replSetAbortPrimaryCatchUp': {'failed': 0,
#                                                          'total': 0},
#                           'replSetFreeze': {'failed': 0, 'total': 0},
#                           'replSetGetConfig': {'failed': 0, 'total': 0},
#                           'replSetGetRBID': {'failed': 0, 'total': 0},
#                           'replSetGetStatus': {'failed': 0, 'total': 0},
#                           'replSetHeartbeat': {'failed': 0, 'total': 0},
#                           'replSetInitiate': {'failed': 0, 'total': 0},
#                           'replSetMaintenance': {'failed': 0, 'total': 0},
#                           'replSetReconfig': {'failed': 0, 'total': 0},
#                           'replSetRequestVotes': {'failed': 0, 'total': 0},
#                           'replSetResizeOplog': {'failed': 0, 'total': 0},
#                           'replSetStepDown': {'failed': 0, 'total': 0},
#                           'replSetStepDownWithForce': {'failed': 0, 'total': 0},
#                           'replSetStepUp': {'failed': 0, 'total': 0},
#                           'replSetSyncFrom': {'failed': 0, 'total': 0},
#                           'replSetUpdatePosition': {'failed': 0, 'total': 0},
#                           'resetError': {'failed': 0, 'total': 0},
#                           'revokePrivilegesFromRole': {'failed': 0, 'total': 0},
#                           'revokeRolesFromRole': {'failed': 0, 'total': 0},
#                           'revokeRolesFromUser': {'failed': 0, 'total': 0},
#                           'rolesInfo': {'failed': 0, 'total': 0},
#                           'saslContinue': {'failed': 0, 'total': 0},
#                           'saslStart': {'failed': 0, 'total': 0},
#                           'serverStatus': {'failed': 0, 'total': 1},
#                           'setFeatureCompatibilityVersion': {'failed': 0,
#                                                              'total': 0},
#                           'setFreeMonitoring': {'failed': 0, 'total': 0},
#                           'setIndexCommitQuorum': {'failed': 0, 'total': 0},
#                           'setParameter': {'failed': 0, 'total': 0},
#                           'setShardVersion': {'failed': 0, 'total': 0},
#                           'shardConnPoolStats': {'failed': 0, 'total': 0},
#                           'shardingState': {'failed': 0, 'total': 0},
#                           'shutdown': {'failed': 0, 'total': 0},
#                           'splitChunk': {'failed': 0, 'total': 0},
#                           'splitVector': {'failed': 0, 'total': 0},
#                           'startRecordingTraffic': {'failed': 0, 'total': 0},
#                           'startSession': {'failed': 0, 'total': 0},
#                           'stopRecordingTraffic': {'failed': 0, 'total': 0},
#                           'top': {'failed': 0, 'total': 0},
#                           'touch': {'failed': 0, 'total': 0},
#                           'unsetSharding': {'failed': 0, 'total': 0},
#                           'update': {'failed': 0, 'total': 0},
#                           'updateRole': {'failed': 0, 'total': 0},
#                           'updateUser': {'failed': 0, 'total': 0},
#                           'usersInfo': {'failed': 0, 'total': 0},
#                           'validate': {'failed': 0, 'total': 0},
#                           'voteCommitIndexBuild': {'failed': 0, 'total': 0},
#                           'waitForFailPoint': {'failed': 0, 'total': 0},
#                           'whatsmyuri': {'failed': 0, 'total': 0}},
#              'cursor': {'open': {'noTimeout': 0, 'pinned': 0, 'total': 0},
#                         'timedOut': 0},
#              'document': {'deleted': 0,
#                           'inserted': 0,
#                           'returned': 0,
#                           'updated': 0},
#              'getLastError': {'wtime': {'num': 0, 'totalMillis': 0},
#                               'wtimeouts': 0},
#              'operation': {'scanAndOrder': 0, 'writeConflicts': 0},
#              'query': {'planCacheTotalSizeEstimateBytes': 0,
#                        'updateOneOpStyleBroadcastWithExactIDCount': 0},
#              'queryExecutor': {'scanned': 0, 'scannedObjects': 0},
#              'record': {'moves': 0},
#              'repl': {'apply': {'attemptsToBecomeSecondary': 0,
#                                 'batchSize': 0,
#                                 'batches': {'num': 0, 'totalMillis': 0},
#                                 'ops': 0},
#                       'buffer': {'count': 0, 'maxSizeBytes': 0, 'sizeBytes': 0},
#                       'executor': {'networkInterface': 'DEPRECATED: '
#                                                        'getDiagnosticString is '
#                                                        'deprecated in '
#                                                        'NetworkInterfaceTL',
#                                    'pool': {'inProgressCount': 0},
#                                    'queues': {'networkInProgress': 0,
#                                               'sleepers': 0},
#                                    'shuttingDown': False,
#                                    'unsignaledEvents': 0},
#                       'initialSync': {'completed': 0,
#                                       'failedAttempts': 0,
#                                       'failures': 0},
#                       'network': {'bytes': 0,
#                                   'getmores': {'num': 0, 'totalMillis': 0},
#                                   'notMasterLegacyUnacknowledgedWrites': 0,
#                                   'notMasterUnacknowledgedWrites': 0,
#                                   'ops': 0,
#                                   'readersCreated': 0},
#                       'stateTransition': {'lastStateTransition': '',
#                                           'userOperationsKilled': 0,
#                                           'userOperationsRunning': 0}},
#              'ttl': {'deletedDocuments': 0, 'passes': 6}},
#  'network': {'bytesIn': 678,
#              'bytesOut': 514,
#              'compression': {'snappy': {'compressor': {'bytesIn': 0,
#                                                        'bytesOut': 0},
#                                         'decompressor': {'bytesIn': 0,
#                                                          'bytesOut': 0}},
#                              'zlib': {'compressor': {'bytesIn': 0,
#                                                      'bytesOut': 0},
#                                       'decompressor': {'bytesIn': 0,
#                                                        'bytesOut': 0}},
#                              'zstd': {'compressor': {'bytesIn': 0,
#                                                      'bytesOut': 0},
#                                       'decompressor': {'bytesIn': 0,
#                                                        'bytesOut': 0}}},
#              'numRequests': 3,
#              'physicalBytesIn': 678,
#              'physicalBytesOut': 514,
#              'serviceExecutorTaskStats': {'executor': 'passthrough',
#                                           'threadsRunning': 2}},
#  'ok': 1.0,
#  'opLatencies': {'commands': {'latency': 314, 'ops': 2},
#                  'reads': {'latency': 0, 'ops': 0},
#                  'transactions': {'latency': 0, 'ops': 0},
#                  'writes': {'latency': 0, 'ops': 0}},
#  'opReadConcernCounters': {'available': 0,
#                            'linearizable': 0,
#                            'local': 0,
#                            'majority': 0,
#                            'none': 2,
#                            'snapshot': 0},
#  'opcounters': {'command': 8,
#                 'delete': 0,
#                 'getmore': 0,
#                 'insert': 0,
#                 'query': 2,
#                 'update': 0},
#  'opcountersRepl': {'command': 0,
#                     'delete': 0,
#                     'getmore': 0,
#                     'insert': 0,
#                     'query': 0,
#                     'update': 0},
#  'pid': 16160,
#  'process': 'C:\\Program Files\\MongoDB\\Server\\4.2\\bin\\mongod.exe',
#  'storageEngine': {'backupCursorOpen': False,
#                    'dropPendingIdents': 0,
#                    'name': 'wiredTiger',
#                    'oldestRequiredTimestampForCrashRecovery': Timestamp(0, 0),
#                    'persistent': True,
#                    'readOnly': False,
#                    'supportsCommittedReads': True,
#                    'supportsPendingDrops': True,
#                    'supportsSnapshotReadConcern': True},
#  'tcmalloc': {'generic': {'current_allocated_bytes': 81174136,
#                           'heap_size': 82706432},
#               'tcmalloc': {'aggressive_memory_decommit': 0,
#                            'central_cache_free_bytes': 181344,
#                            'current_total_thread_cache_bytes': 298024,
#                            'formattedString': '------------------------------------------------\n'
#                                               'MALLOC:       81174136 (   77.4 '
#                                               'MiB) Bytes in use by '
#                                               'application\n'
#                                               'MALLOC: +      1044480 (    1.0 '
#                                               'MiB) Bytes in page heap '
#                                               'freelist\n'
#                                               'MALLOC: +       181344 (    0.2 '
#                                               'MiB) Bytes in central cache '
#                                               'freelist\n'
#                                               'MALLOC: +         8448 (    0.0 '
#                                               'MiB) Bytes in transfer cache '
#                                               'freelist\n'
#                                               'MALLOC: +       298024 (    0.3 '
#                                               'MiB) Bytes in thread cache '
#                                               'freelists\n'
#                                               'MALLOC: +      2752512 (    2.6 '
#                                               'MiB) Bytes in malloc metadata\n'
#                                               'MALLOC:   ------------\n'
#                                               'MALLOC: =     85458944 (   81.5 '
#                                               'MiB) Actual memory used '
#                                               '(physical + swap)\n'
#                                               'MALLOC: +            0 (    0.0 '
#                                               'MiB) Bytes released to OS (aka '
#                                               'unmapped)\n'
#                                               'MALLOC:   ------------\n'
#                                               'MALLOC: =     85458944 (   81.5 '
#                                               'MiB) Virtual address space '
#                                               'used\n'
#                                               'MALLOC:\n'
#                                               'MALLOC:            '
#                                               '298              Spans in use\n'
#                                               'MALLOC:             '
#                                               '12              Thread heaps in '
#                                               'use\n'
#                                               'MALLOC:           '
#                                               '4096              Tcmalloc page '
#                                               'size\n'
#                                               '------------------------------------------------\n'
#                                               'Call ReleaseFreeMemory() to '
#                                               'release freelist memory to the '
#                                               'OS (via madvise()).\n'
#                                               'Bytes released to the OS take '
#                                               'up virtual address space but no '
#                                               'physical memory.\n',
#                            'max_total_thread_cache_bytes': 1048576000,
#                            'pageheap_commit_count': 41,
#                            'pageheap_committed_bytes': 82706432,
#                            'pageheap_decommit_count': 0,
#                            'pageheap_free_bytes': 1044480,
#                            'pageheap_reserve_count': 41,
#                            'pageheap_scavenge_count': 0,
#                            'pageheap_total_commit_bytes': 82706432,
#                            'pageheap_total_decommit_bytes': 0,
#                            'pageheap_total_reserve_bytes': 82706432,
#                            'pageheap_unmapped_bytes': 0,
#                            'release_rate': 1.0,
#                            'spinlock_total_delay_ns': 0,
#                            'thread_cache_free_bytes': 298024,
#                            'total_free_bytes': 487816,
#                            'transfer_cache_free_bytes': 8448}},
#  'trafficRecording': {'running': False},
#  'transactions': {'currentActive': 0,
#                   'currentInactive': 0,
#                   'currentOpen': 0,
#                   'currentPrepared': 0,
#                   'retriedCommandsCount': 0,
#                   'retriedStatementsCount': 0,
#                   'totalAborted': 0,
#                   'totalCommitted': 0,
#                   'totalPrepared': 0,
#                   'totalPreparedThenAborted': 0,
#                   'totalPreparedThenCommitted': 0,
#                   'totalStarted': 0,
#                   'transactionsCollectionWriteCount': 0},
#  'transportSecurity': {'1.0': 0, '1.1': 0, '1.2': 0, '1.3': 0, 'unknown': 0},
#  'twoPhaseCommitCoordinator': {'currentInSteps': {'deletingCoordinatorDoc': 0,
#                                                   'waitingForDecisionAcks': 0,
#                                                   'waitingForVotes': 0,
#                                                   'writingDecision': 0,
#                                                   'writingParticipantList': 0},
#                                'totalAbortedTwoPhaseCommit': 0,
#                                'totalCommittedTwoPhaseCommit': 0,
#                                'totalCreated': 0,
#                                'totalStartedTwoPhaseCommit': 0},
#  'uptime': 381.0,
#  'uptimeEstimate': 381,
#  'uptimeMillis': 381159,
#  'version': '4.2.3',
#  'wiredTiger': {'async': {'current work queue length': 0,
#                           'maximum work queue length': 0,
#                           'number of allocation state races': 0,
#                           'number of flush calls': 0,
#                           'number of operation slots viewed for allocation': 0,
#                           'number of times operation allocation failed': 0,
#                           'number of times worker found no work': 0,
#                           'total allocations': 0,
#                           'total compact calls': 0,
#                           'total insert calls': 0,
#                           'total remove calls': 0,
#                           'total search calls': 0,
#                           'total update calls': 0},
#                 'block-manager': {'blocks pre-loaded': 0,
#                                   'blocks read': 3,
#                                   'blocks written': 38,
#                                   'bytes read': 12288,
#                                   'bytes written': 192512,
#                                   'bytes written for checkpoint': 192512,
#                                   'mapped blocks read': 0,
#                                   'mapped bytes read': 0},
#                 'cache': {'application threads page read from disk to cache count': 0,
#                           'application threads page read from disk to cache time (usecs)': 0,
#                           'application threads page write from cache to disk count': 18,
#                           'application threads page write from cache to disk time (usecs)': 1500,
#                           'bytes belonging to page images in the cache': 0,
#                           'bytes belonging to the cache overflow table in the cache': 182,
#                           'bytes currently in the cache': 43635,
#                           'bytes dirty in the cache cumulative': 9178,
#                           'bytes not belonging to page images in the cache': 43635,
#                           'bytes read into cache': 0,
#                           'bytes written from cache': 43561,
#                           'cache overflow cursor application thread wait time (usecs)': 0,
#                           'cache overflow cursor internal thread wait time (usecs)': 0,
#                           'cache overflow score': 0,
#                           'cache overflow table entries': 0,
#                           'cache overflow table insert calls': 0,
#                           'cache overflow table max on-disk size': 0,
#                           'cache overflow table on-disk size': 0,
#                           'cache overflow table remove calls': 0,
#                           'checkpoint blocked page eviction': 0,
#                           'eviction calls to get a page': 13,
#                           'eviction calls to get a page found queue empty': 12,
#                           'eviction calls to get a page found queue empty after locking': 0,
#                           'eviction currently operating in aggressive mode': 0,
#                           'eviction empty score': 0,
#                           'eviction passes of a file': 0,
#                           'eviction server candidate queue empty when topping up': 0,
#                           'eviction server candidate queue not empty when topping up': 0,
#                           'eviction server evicting pages': 0,
#                           'eviction server slept, because we did not make progress with eviction': 0,
#                           'eviction server unable to reach eviction goal': 0,
#                           'eviction server waiting for a leaf page': 2,
#                           'eviction state': 128,
#                           'eviction walk target pages histogram - 0-9': 0,
#                           'eviction walk target pages histogram - 10-31': 0,
#                           'eviction walk target pages histogram - 128 and higher': 0,
#                           'eviction walk target pages histogram - 32-63': 0,
#                           'eviction walk target pages histogram - 64-128': 0,
#                           'eviction walk target strategy both clean and dirty pages': 0,
#                           'eviction walk target strategy only clean pages': 0,
#                           'eviction walk target strategy only dirty pages': 0,
#                           'eviction walks abandoned': 0,
#                           'eviction walks gave up because they restarted their walk twice': 0,
#                           'eviction walks gave up because they saw too many pages and found no candidates': 0,
#                           'eviction walks gave up because they saw too many pages and found too few candidates': 0,
#                           'eviction walks reached end of tree': 0,
#                           'eviction walks started from root of tree': 0,
#                           'eviction walks started from saved location in tree': 0,
#                           'eviction worker thread active': 4,
#                           'eviction worker thread created': 0,
#                           'eviction worker thread evicting pages': 0,
#                           'eviction worker thread removed': 0,
#                           'eviction worker thread stable number': 0,
#                           'files with active eviction walks': 0,
#                           'files with new eviction walks started': 0,
#                           'force re-tuning of eviction workers once in a while': 0,
#                           'forced eviction - pages evicted that were clean count': 0,
#                           'forced eviction - pages evicted that were clean time (usecs)': 0,
#                           'forced eviction - pages evicted that were dirty count': 0,
#                           'forced eviction - pages evicted that were dirty time (usecs)': 0,
#                           'forced eviction - pages selected because of too many deleted items count': 0,
#                           'forced eviction - pages selected count': 0,
#                           'forced eviction - pages selected unable to be evicted count': 0,
#                           'forced eviction - pages selected unable to be evicted time': 0,
#                           'hazard pointer blocked page eviction': 0,
#                           'hazard pointer check calls': 0,
#                           'hazard pointer check entries walked': 0,
#                           'hazard pointer maximum array length': 0,
#                           'in-memory page passed criteria to be split': 0,
#                           'in-memory page splits': 0,
#                           'internal pages evicted': 0,
#                           'internal pages queued for eviction': 0,
#                           'internal pages seen by eviction walk': 0,
#                           'internal pages seen by eviction walk that are already queued': 0,
#                           'internal pages split during eviction': 0,
#                           'leaf pages split during eviction': 0,
#                           'maximum bytes configured': 3658481664.0,
#                           'maximum page size at eviction': 0,
#                           'modified pages evicted': 2,
#                           'modified pages evicted by application threads': 0,
#                           'operations timed out waiting for space in cache': 0,
#                           'overflow pages read into cache': 0,
#                           'page split during eviction deepened the tree': 0,
#                           'page written requiring cache overflow records': 0,
#                           'pages currently held in the cache': 19,
#                           'pages evicted by application threads': 0,
#                           'pages queued for eviction': 0,
#                           'pages queued for eviction post lru sorting': 0,
#                           'pages queued for urgent eviction': 0,
#                           'pages queued for urgent eviction during walk': 0,
#                           'pages read into cache': 0,
#                           'pages read into cache after truncate': 8,
#                           'pages read into cache after truncate in prepare state': 0,
#                           'pages read into cache requiring cache overflow entries': 0,
#                           'pages read into cache requiring cache overflow for checkpoint': 0,
#                           'pages read into cache skipping older cache overflow entries': 0,
#                           'pages read into cache with skipped cache overflow entries needed later': 0,
#                           'pages read into cache with skipped cache overflow entries needed later by checkpoint': 0,
#                           'pages requested from the cache': 364,
#                           'pages seen by eviction walk': 0,
#                           'pages seen by eviction walk that are already queued': 0,
#                           'pages selected for eviction unable to be evicted': 0,
#                           'pages selected for eviction unable to be evicted as the parent page has overflow items': 0,
#                           'pages selected for eviction unable to be evicted because of active children on an internal page': 0,
#                           'pages selected for eviction unable to be evicted because of failure in reconciliation': 0,
#                           'pages selected for eviction unable to be evicted due to newer modifications on a clean page': 0,
#                           'pages walked for eviction': 0,
#                           'pages written from cache': 18,
#                           'pages written requiring in-memory restoration': 0,
#                           'percentage overhead': 8,
#                           'tracked bytes belonging to internal pages in the cache': 4227,
#                           'tracked bytes belonging to leaf pages in the cache': 39408,
#                           'tracked dirty bytes in the cache': 0,
#                           'tracked dirty pages in the cache': 0,
#                           'unmodified pages evicted': 0},
#                 'capacity': {'background fsync file handles considered': 0,
#                              'background fsync file handles synced': 0,
#                              'background fsync time (msecs)': 0,
#                              'bytes read': 0,
#                              'bytes written for checkpoint': 43103,
#                              'bytes written for eviction': 0,
#                              'bytes written for log': 24576,
#                              'bytes written total': 67679,
#                              'threshold to call fsync': 0,
#                              'time waiting due to total capacity (usecs)': 0,
#                              'time waiting during checkpoint (usecs)': 0,
#                              'time waiting during eviction (usecs)': 0,
#                              'time waiting during logging (usecs)': 0,
#                              'time waiting during read (usecs)': 0},
#                 'concurrentTransactions': {'read': {'available': 127,
#                                                     'out': 1,
#                                                     'totalTickets': 128},
#                                            'write': {'available': 128,
#                                                      'out': 0,
#                                                      'totalTickets': 128}},
#                 'connection': {'auto adjusting condition resets': 27,
#                                'auto adjusting condition wait calls': 2343,
#                                'detected system time went backwards': 0,
#                                'files currently open': 14,
#                                'memory allocations': 15714,
#                                'memory frees': 14717,
#                                'memory re-allocations': 1783,
#                                'pthread mutex condition wait calls': 6342,
#                                'pthread mutex shared lock read-lock calls': 4482,
#                                'pthread mutex shared lock write-lock calls': 469,
#                                'total fsync I/Os': 62,
#                                'total read I/Os': 24,
#                                'total write I/Os': 79},
#                 'cursor': {'cached cursor count': 11,
#                            'cursor bulk loaded cursor insert calls': 0,
#                            'cursor close calls that result in cache': 33,
#                            'cursor create calls': 79,
#                            'cursor insert calls': 61,
#                            'cursor insert key and value bytes': 30933,
#                            'cursor modify calls': 0,
#                            'cursor modify key and value bytes affected': 0,
#                            'cursor modify value bytes modified': 0,
#                            'cursor next calls': 34,
#                            'cursor operation restarted': 0,
#                            'cursor prev calls': 10,
#                            'cursor remove calls': 3,
#                            'cursor remove key bytes removed': 116,
#                            'cursor reserve calls': 0,
#                            'cursor reset calls': 382,
#                            'cursor search calls': 269,
#                            'cursor search near calls': 13,
#                            'cursor sweep buckets': 72,
#                            'cursor sweep cursors closed': 0,
#                            'cursor sweep cursors examined': 2,
#                            'cursor sweeps': 12,
#                            'cursor truncate calls': 0,
#                            'cursor update calls': 0,
#                            'cursor update key and value bytes': 0,
#                            'cursor update value size change': 0,
#                            'cursors reused from cache': 21,
#                            'open cursor count': 21},
#                 'data-handle': {'connection data handle size': 432,
#                                 'connection data handles currently active': 21,
#                                 'connection sweep candidate became referenced': 0,
#                                 'connection sweep dhandles closed': 1,
#                                 'connection sweep dhandles removed from hash list': 3,
#                                 'connection sweep time-of-death sets': 34,
#                                 'connection sweeps': 38,
#                                 'session dhandles swept': 2,
#                                 'session sweep attempts': 38},
#                 'lock': {'checkpoint lock acquisitions': 6,
#                          'checkpoint lock application thread wait time (usecs)': 0,
#                          'checkpoint lock internal thread wait time (usecs)': 0,
#                          'dhandle lock application thread time waiting (usecs)': 0,
#                          'dhandle lock internal thread time waiting (usecs)': 0,
#                          'dhandle read lock acquisitions': 1558,
#                          'dhandle write lock acquisitions': 28,
#                          'durable timestamp queue lock application thread time waiting (usecs)': 0,
#                          'durable timestamp queue lock internal thread time waiting (usecs)': 0,
#                          'durable timestamp queue read lock acquisitions': 0,
#                          'durable timestamp queue write lock acquisitions': 0,
#                          'metadata lock acquisitions': 3,
#                          'metadata lock application thread wait time (usecs)': 0,
#                          'metadata lock internal thread wait time (usecs)': 0,
#                          'read timestamp queue lock application thread time waiting (usecs)': 0,
#                          'read timestamp queue lock internal thread time waiting (usecs)': 0,
#                          'read timestamp queue read lock acquisitions': 0,
#                          'read timestamp queue write lock acquisitions': 0,
#                          'schema lock acquisitions': 20,
#                          'schema lock application thread wait time (usecs)': 0,
#                          'schema lock internal thread wait time (usecs)': 0,
#                          'table lock application thread time waiting for the table lock (usecs)': 0,
#                          'table lock internal thread time waiting for the table lock (usecs)': 0,
#                          'table read lock acquisitions': 0,
#                          'table write lock acquisitions': 13,
#                          'txn global lock application thread time waiting (usecs)': 0,
#                          'txn global lock internal thread time waiting (usecs)': 0,
#                          'txn global read lock acquisitions': 21,
#                          'txn global write lock acquisitions': 12},
#                 'log': {'busy returns attempting to switch slots': 0,
#                         'force archive time sleeping (usecs)': 0,
#                         'log bytes of payload data': 18213,
#                         'log bytes written': 24448,
#                         'log files manually zero-filled': 0,
#                         'log flush operations': 3794,
#                         'log force write operations': 4194,
#                         'log force write operations skipped': 4189,
#                         'log records compressed': 20,
#                         'log records not compressed': 18,
#                         'log records too small to compress': 27,
#                         'log release advances write LSN': 16,
#                         'log scan operations': 0,
#                         'log scan records requiring two reads': 0,
#                         'log server thread advances write LSN': 5,
#                         'log server thread write LSN walk skipped': 1377,
#                         'log sync operations': 21,
#                         'log sync time duration (usecs)': 59528,
#                         'log sync_dir operations': 1,
#                         'log sync_dir time duration (usecs)': 0,
#                         'log write operations': 65,
#                         'logging bytes consolidated': 23936,
#                         'maximum log file size': 104857600,
#                         'number of pre-allocated log files to create': 2,
#                         'pre-allocated log files not ready and missed': 1,
#                         'pre-allocated log files prepared': 2,
#                         'pre-allocated log files used': 0,
#                         'records processed by log scan': 0,
#                         'slot close lost race': 0,
#                         'slot close unbuffered waits': 0,
#                         'slot closures': 21,
#                         'slot join atomic update races': 0,
#                         'slot join calls atomic updates raced': 0,
#                         'slot join calls did not yield': 65,
#                         'slot join calls found active slot closed': 0,
#                         'slot join calls slept': 0,
#                         'slot join calls yielded': 0,
#                         'slot join found active slot closed': 0,
#                         'slot joins yield time (usecs)': 0,
#                         'slot transitions unable to find free slot': 0,
#                         'slot unbuffered writes': 0,
#                         'total in-memory size of compressed records': 28821,
#                         'total log buffer size': 33554432,
#                         'total size of compressed records': 14473,
#                         'written slots coalesced': 0,
#                         'yields waiting for previous log file close': 0},
#                 'perf': {'file system read latency histogram (bucket 1) - 10-49ms': 0,
#                          'file system read latency histogram (bucket 2) - 50-99ms': 0,
#                          'file system read latency histogram (bucket 3) - 100-249ms': 0,
#                          'file system read latency histogram (bucket 4) - 250-499ms': 0,
#                          'file system read latency histogram (bucket 5) - 500-999ms': 0,
#                          'file system read latency histogram (bucket 6) - 1000ms+': 0,
#                          'file system write latency histogram (bucket 1) - 10-49ms': 0,
#                          'file system write latency histogram (bucket 2) - 50-99ms': 0,
#                          'file system write latency histogram (bucket 3) - 100-249ms': 0,
#                          'file system write latency histogram (bucket 4) - 250-499ms': 0,
#                          'file system write latency histogram (bucket 5) - 500-999ms': 0,
#                          'file system write latency histogram (bucket 6) - 1000ms+': 0,
#                          'operation read latency histogram (bucket 1) - 100-249us': 0,
#                          'operation read latency histogram (bucket 2) - 250-499us': 2,
#                          'operation read latency histogram (bucket 3) - 500-999us': 0,
#                          'operation read latency histogram (bucket 4) - 1000-9999us': 0,
#                          'operation read latency histogram (bucket 5) - 10000us+': 0,
#                          'operation write latency histogram (bucket 1) - 100-249us': 0,
#                          'operation write latency histogram (bucket 2) - 250-499us': 2,
#                          'operation write latency histogram (bucket 3) - 500-999us': 2,
#                          'operation write latency histogram (bucket 4) - 1000-9999us': 0,
#                          'operation write latency histogram (bucket 5) - 10000us+': 0},
#                 'reconciliation': {'fast-path pages deleted': 0,
#                                    'page reconciliation calls': 21,
#                                    'page reconciliation calls for eviction': 1,
#                                    'pages deleted': 4,
#                                    'split bytes currently awaiting free': 0,
#                                    'split objects currently awaiting free': 0},
#                 'session': {'open session count': 18,
#                             'session query timestamp calls': 0,
#                             'table alter failed calls': 0,
#                             'table alter successful calls': 0,
#                             'table alter unchanged and skipped': 0,
#                             'table compact failed calls': 0,
#                             'table compact successful calls': 0,
#                             'table create failed calls': 0,
#                             'table create successful calls': 10,
#                             'table drop failed calls': 0,
#                             'table drop successful calls': 1,
#                             'table import failed calls': 0,
#                             'table import successful calls': 0,
#                             'table rebalance failed calls': 0,
#                             'table rebalance successful calls': 0,
#                             'table rename failed calls': 0,
#                             'table rename successful calls': 0,
#                             'table salvage failed calls': 0,
#                             'table salvage successful calls': 0,
#                             'table truncate failed calls': 0,
#                             'table truncate successful calls': 0,
#                             'table verify failed calls': 0,
#                             'table verify successful calls': 0},
#                 'snapshot-window-settings': {'cache pressure percentage threshold': 95,
#                                              'current available snapshots window size in seconds': 0,
#                                              'current cache pressure percentage': 0,
#                                              'latest majority snapshot timestamp available': 'Dec '
#                                                                                              '31 '
#                                                                                              '17:00:00:0',
#                                              'max target available snapshots window size in seconds': 5,
#                                              'oldest majority snapshot timestamp available': 'Dec '
#                                                                                              '31 '
#                                                                                              '17:00:00:0',
#                                              'target available snapshots window size in seconds': 5,
#                                              'total number of SnapshotTooOld errors': 0},
#                 'thread-state': {'active filesystem fsync calls': 0,
#                                  'active filesystem read calls': 0,
#                                  'active filesystem write calls': 0},
#                 'thread-yield': {'application thread time evicting (usecs)': 0,
#                                  'application thread time waiting for cache (usecs)': 0,
#                                  'connection close blocked waiting for transaction state stabilization': 0,
#                                  'connection close yielded for lsm manager shutdown': 0,
#                                  'data handle lock yielded': 0,
#                                  'get reference for page index and slot time sleeping (usecs)': 0,
#                                  'log server sync yielded for log write': 0,
#                                  'page access yielded due to prepare state change': 0,
#                                  'page acquire busy blocked': 0,
#                                  'page acquire eviction blocked': 0,
#                                  'page acquire locked blocked': 0,
#                                  'page acquire read blocked': 0,
#                                  'page acquire time sleeping (usecs)': 0,
#                                  'page delete rollback time sleeping for state change (usecs)': 0,
#                                  'page reconciliation yielded due to child modification': 0},
#                 'transaction': {'Number of prepared updates': 0,
#                                 'Number of prepared updates added to cache overflow': 0,
#                                 'durable timestamp queue entries walked': 0,
#                                 'durable timestamp queue insert to empty': 0,
#                                 'durable timestamp queue inserts to head': 0,
#                                 'durable timestamp queue inserts total': 0,
#                                 'durable timestamp queue length': 0,
#                                 'number of named snapshots created': 0,
#                                 'number of named snapshots dropped': 0,
#                                 'prepared transactions': 0,
#                                 'prepared transactions committed': 0,
#                                 'prepared transactions currently active': 0,
#                                 'prepared transactions rolled back': 0,
#                                 'query timestamp calls': 381,
#                                 'read timestamp queue entries walked': 0,
#                                 'read timestamp queue insert to empty': 0,
#                                 'read timestamp queue inserts to head': 0,
#                                 'read timestamp queue inserts total': 0,
#                                 'read timestamp queue length': 0,
#                                 'rollback to stable calls': 0,
#                                 'rollback to stable updates aborted': 0,
#                                 'rollback to stable updates removed from cache overflow': 0,
#                                 'set timestamp calls': 0,
#                                 'set timestamp durable calls': 0,
#                                 'set timestamp durable updates': 0,
#                                 'set timestamp oldest calls': 0,
#                                 'set timestamp oldest updates': 0,
#                                 'set timestamp stable calls': 0,
#                                 'set timestamp stable updates': 0,
#                                 'transaction begins': 32,
#                                 'transaction checkpoint currently running': 0,
#                                 'transaction checkpoint generation': 4,
#                                 'transaction checkpoint max time (msecs)': 31,
#                                 'transaction checkpoint min time (msecs)': 18,
#                                 'transaction checkpoint most recent time (msecs)': 18,
#                                 'transaction checkpoint scrub dirty target': 0,
#                                 'transaction checkpoint scrub time (msecs)': 0,
#                                 'transaction checkpoint total time (msecs)': 74,
#                                 'transaction checkpoints': 6,
#                                 'transaction checkpoints skipped because database was clean': 3,
#                                 'transaction failures due to cache overflow': 0,
#                                 'transaction fsync calls for checkpoint after allocating the transaction ID': 3,
#                                 'transaction fsync duration for checkpoint after allocating the transaction ID (usecs)': 0,
#                                 'transaction range of IDs currently pinned': 0,
#                                 'transaction range of IDs currently pinned by a checkpoint': 0,
#                                 'transaction range of IDs currently pinned by named snapshots': 0,
#                                 'transaction range of timestamps currently pinned': 0,
#                                 'transaction range of timestamps pinned by a checkpoint': 0,
#                                 'transaction range of timestamps pinned by the oldest active read timestamp': 0,
#                                 'transaction range of timestamps pinned by the oldest timestamp': 0,
#                                 'transaction read timestamp of the oldest active reader': 0,
#                                 'transaction sync calls': 0,
#                                 'transactions committed': 9,
#                                 'transactions rolled back': 23,
#                                 'update conflicts': 0},
#                 'uri': 'statistics:'}}

# %%
from pymongo import MongoClient
from random import randint
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient(port=27017)
db = client.business

#Step 2: Create sample data
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']

for x in range(1, 51):
    business = {
        'name' : names[randint(0, (len(names)-1))] + ' ' + names[randint(0, (len(names)-1))]  + ' ' + company_type[randint(0, (len(company_type)-1))],
        'rating' : randint(1, 5),
        'cuisine' : company_cuisine[randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via insert_one
#     if business['_id'] in 
    result=db.reviews.insert_one(business)
    
    #Step 4: Print to the console the ObjectID of the new document
    print('Created {0} of 50 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
# Out:
# Created 1 of 50 as 5e3a597f58ae7e568577b2e3
# Created 2 of 50 as 5e3a597f58ae7e568577b2e4
# Created 3 of 50 as 5e3a597f58ae7e568577b2e5
# Created 4 of 50 as 5e3a597f58ae7e568577b2e6
# Created 5 of 50 as 5e3a597f58ae7e568577b2e7
# Created 6 of 50 as 5e3a597f58ae7e568577b2e8
# Created 7 of 50 as 5e3a597f58ae7e568577b2e9
# Created 8 of 50 as 5e3a597f58ae7e568577b2ea
# Created 9 of 50 as 5e3a597f58ae7e568577b2eb
# Created 10 of 50 as 5e3a597f58ae7e568577b2ec
# Created 11 of 50 as 5e3a597f58ae7e568577b2ed
# Created 12 of 50 as 5e3a597f58ae7e568577b2ee
# Created 13 of 50 as 5e3a597f58ae7e568577b2ef
# Created 14 of 50 as 5e3a597f58ae7e568577b2f0
# Created 15 of 50 as 5e3a597f58ae7e568577b2f1
# Created 16 of 50 as 5e3a597f58ae7e568577b2f2
# Created 17 of 50 as 5e3a597f58ae7e568577b2f3
# Created 18 of 50 as 5e3a597f58ae7e568577b2f4
# Created 19 of 50 as 5e3a597f58ae7e568577b2f5
# Created 20 of 50 as 5e3a597f58ae7e568577b2f6
# Created 21 of 50 as 5e3a597f58ae7e568577b2f7
# Created 22 of 50 as 5e3a597f58ae7e568577b2f8
# Created 23 of 50 as 5e3a597f58ae7e568577b2f9
# Created 24 of 50 as 5e3a597f58ae7e568577b2fa
# Created 25 of 50 as 5e3a597f58ae7e568577b2fb
# Created 26 of 50 as 5e3a597f58ae7e568577b2fc
# Created 27 of 50 as 5e3a597f58ae7e568577b2fd
# Created 28 of 50 as 5e3a597f58ae7e568577b2fe
# Created 29 of 50 as 5e3a597f58ae7e568577b2ff
# Created 30 of 50 as 5e3a597f58ae7e568577b300
# Created 31 of 50 as 5e3a597f58ae7e568577b301
# Created 32 of 50 as 5e3a597f58ae7e568577b302
# Created 33 of 50 as 5e3a597f58ae7e568577b303
# Created 34 of 50 as 5e3a597f58ae7e568577b304
# Created 35 of 50 as 5e3a597f58ae7e568577b305
# Created 36 of 50 as 5e3a597f58ae7e568577b306
# Created 37 of 50 as 5e3a597f58ae7e568577b307
# Created 38 of 50 as 5e3a597f58ae7e568577b308
# Created 39 of 50 as 5e3a597f58ae7e568577b309
# Created 40 of 50 as 5e3a597f58ae7e568577b30a
# Created 41 of 50 as 5e3a597f58ae7e568577b30b
# Created 42 of 50 as 5e3a597f58ae7e568577b30c
# Created 43 of 50 as 5e3a597f58ae7e568577b30d
# Created 44 of 50 as 5e3a597f58ae7e568577b30e
# Created 45 of 50 as 5e3a597f58ae7e568577b30f
# Created 46 of 50 as 5e3a597f58ae7e568577b310
# Created 47 of 50 as 5e3a597f58ae7e568577b311
# Created 48 of 50 as 5e3a597f58ae7e568577b312
# Created 49 of 50 as 5e3a597f58ae7e568577b313
# Created 50 of 50 as 5e3a597f58ae7e568577b314
# finished creating 500 business reviews

# %%
fivestar = db.reviews.find_one({'rating':5})
print(fivestar)
# Out:
# {'_id': ObjectId('5e37fce4c627b31519dd0659'), 'name': 'Goat Pizza Inc', 'rating': 5, 'cuisine': 'American'}

# %%
db.reviews.find_one({})
# Out:
# {'_id': ObjectId('5e37fce4c627b31519dd0656'),
#  'name': 'Salty Goat Company',
#  'rating': 1,
#  'cuisine': 'Vegetarian'}

# %%
db.business
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'business'), 'business')

# %%
from pymongo import MongoClient
from random import randint
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient(port=27017)
test_db = client.test
#Step 2: Create sample data
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']
for x in range(1, 501):
    business = {
        'name' : names[randint(0, (len(names)-1))] + ' ' + names[randint(0, (len(names)-1))]  + ' ' + company_type[randint(0, (len(company_type)-1))],
        'rating' : randint(1, 5),
        'cuisine' : company_cuisine[randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via isnert_one
    result=test_db.reviews.insert_one(business)
    #Step 4: Print to the console the ObjectID of the new document
    print('Created {0} of 500 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
# Out:
# Created 1 of 500 as 5e37ffadc627b31519dd0e2e
# Created 2 of 500 as 5e37ffadc627b31519dd0e2f
# Created 3 of 500 as 5e37ffadc627b31519dd0e30
# Created 4 of 500 as 5e37ffadc627b31519dd0e31
# Created 5 of 500 as 5e37ffadc627b31519dd0e32
# Created 6 of 500 as 5e37ffadc627b31519dd0e33
# Created 7 of 500 as 5e37ffadc627b31519dd0e34
# Created 8 of 500 as 5e37ffadc627b31519dd0e35
# Created 9 of 500 as 5e37ffadc627b31519dd0e36
# Created 10 of 500 as 5e37ffadc627b31519dd0e37
# Created 11 of 500 as 5e37ffadc627b31519dd0e38
# Created 12 of 500 as 5e37ffadc627b31519dd0e39
# Created 13 of 500 as 5e37ffadc627b31519dd0e3a
# Created 14 of 500 as 5e37ffadc627b31519dd0e3b
# Created 15 of 500 as 5e37ffadc627b31519dd0e3c
# Created 16 of 500 as 5e37ffadc627b31519dd0e3d
# Created 17 of 500 as 5e37ffadc627b31519dd0e3e
# Created 18 of 500 as 5e37ffadc627b31519dd0e3f
# Created 19 of 500 as 5e37ffadc627b31519dd0e40
# Created 20 of 500 as 5e37ffadc627b31519dd0e41
# Created 21 of 500 as 5e37ffadc627b31519dd0e42
# Created 22 of 500 as 5e37ffadc627b31519dd0e43
# Created 23 of 500 as 5e37ffadc627b31519dd0e44
# Created 24 of 500 as 5e37ffadc627b31519dd0e45
# Created 25 of 500 as 5e37ffadc627b31519dd0e46
# Created 26 of 500 as 5e37ffadc627b31519dd0e47
# Created 27 of 500 as 5e37ffadc627b31519dd0e48
# Created 28 of 500 as 5e37ffadc627b31519dd0e49
# Created 29 of 500 as 5e37ffadc627b31519dd0e4a
# Created 30 of 500 as 5e37ffadc627b31519dd0e4b
# Created 31 of 500 as 5e37ffadc627b31519dd0e4c
# Created 32 of 500 as 5e37ffadc627b31519dd0e4d
# Created 33 of 500 as 5e37ffadc627b31519dd0e4e
# Created 34 of 500 as 5e37ffadc627b31519dd0e4f
# Created 35 of 500 as 5e37ffadc627b31519dd0e50
# Created 36 of 500 as 5e37ffadc627b31519dd0e51
# Created 37 of 500 as 5e37ffadc627b31519dd0e52
# Created 38 of 500 as 5e37ffadc627b31519dd0e53
# Created 39 of 500 as 5e37ffadc627b31519dd0e54
# Created 40 of 500 as 5e37ffadc627b31519dd0e55
# Created 41 of 500 as 5e37ffadc627b31519dd0e56
# Created 42 of 500 as 5e37ffadc627b31519dd0e57
# Created 43 of 500 as 5e37ffadc627b31519dd0e58
# Created 44 of 500 as 5e37ffadc627b31519dd0e59
# Created 45 of 500 as 5e37ffadc627b31519dd0e5a
# Created 46 of 500 as 5e37ffadc627b31519dd0e5b
# Created 47 of 500 as 5e37ffadc627b31519dd0e5c
# Created 48 of 500 as 5e37ffadc627b31519dd0e5d
# Created 49 of 500 as 5e37ffadc627b31519dd0e5e
# Created 50 of 500 as 5e37ffadc627b31519dd0e5f
# Created 51 of 500 as 5e37ffadc627b31519dd0e60
# Created 52 of 500 as 5e37ffadc627b31519dd0e61
# Created 53 of 500 as 5e37ffadc627b31519dd0e62
# Created 54 of 500 as 5e37ffadc627b31519dd0e63
# Created 55 of 500 as 5e37ffadc627b31519dd0e64
# Created 56 of 500 as 5e37ffadc627b31519dd0e65
# Created 57 of 500 as 5e37ffadc627b31519dd0e66
# Created 58 of 500 as 5e37ffadc627b31519dd0e67
# Created 59 of 500 as 5e37ffadc627b31519dd0e68
# Created 60 of 500 as 5e37ffadc627b31519dd0e69
# Created 61 of 500 as 5e37ffadc627b31519dd0e6a
# Created 62 of 500 as 5e37ffadc627b31519dd0e6b
# Created 63 of 500 as 5e37ffadc627b31519dd0e6c
# Created 64 of 500 as 5e37ffadc627b31519dd0e6d
# Created 65 of 500 as 5e37ffadc627b31519dd0e6e
# Created 66 of 500 as 5e37ffadc627b31519dd0e6f
# Created 67 of 500 as 5e37ffadc627b31519dd0e70
# Created 68 of 500 as 5e37ffadc627b31519dd0e71
# Created 69 of 500 as 5e37ffadc627b31519dd0e72
# Created 70 of 500 as 5e37ffadc627b31519dd0e73
# Created 71 of 500 as 5e37ffadc627b31519dd0e74
# Created 72 of 500 as 5e37ffadc627b31519dd0e75
# Created 73 of 500 as 5e37ffadc627b31519dd0e76
# Created 74 of 500 as 5e37ffadc627b31519dd0e77
# Created 75 of 500 as 5e37ffadc627b31519dd0e78
# Created 76 of 500 as 5e37ffadc627b31519dd0e79
# Created 77 of 500 as 5e37ffadc627b31519dd0e7a
# Created 78 of 500 as 5e37ffadc627b31519dd0e7b
# Created 79 of 500 as 5e37ffadc627b31519dd0e7c
# Created 80 of 500 as 5e37ffadc627b31519dd0e7d
# Created 81 of 500 as 5e37ffadc627b31519dd0e7e
# Created 82 of 500 as 5e37ffadc627b31519dd0e7f
# Created 83 of 500 as 5e37ffadc627b31519dd0e80
# Created 84 of 500 as 5e37ffadc627b31519dd0e81
# Created 85 of 500 as 5e37ffadc627b31519dd0e82
# Created 86 of 500 as 5e37ffadc627b31519dd0e83
# Created 87 of 500 as 5e37ffadc627b31519dd0e84
# Created 88 of 500 as 5e37ffadc627b31519dd0e85
# Created 89 of 500 as 5e37ffadc627b31519dd0e86
# Created 90 of 500 as 5e37ffadc627b31519dd0e87
# Created 91 of 500 as 5e37ffadc627b31519dd0e88
# Created 92 of 500 as 5e37ffadc627b31519dd0e89
# Created 93 of 500 as 5e37ffadc627b31519dd0e8a
# Created 94 of 500 as 5e37ffadc627b31519dd0e8b
# Created 95 of 500 as 5e37ffadc627b31519dd0e8c
# Created 96 of 500 as 5e37ffadc627b31519dd0e8d
# Created 97 of 500 as 5e37ffadc627b31519dd0e8e
# Created 98 of 500 as 5e37ffadc627b31519dd0e8f
# Created 99 of 500 as 5e37ffadc627b31519dd0e90
# Created 100 of 500 as 5e37ffadc627b31519dd0e91
# Created 101 of 500 as 5e37ffadc627b31519dd0e92
# Created 102 of 500 as 5e37ffadc627b31519dd0e93
# Created 103 of 500 as 5e37ffadc627b31519dd0e94
# Created 104 of 500 as 5e37ffadc627b31519dd0e95
# Created 105 of 500 as 5e37ffadc627b31519dd0e96
# Created 106 of 500 as 5e37ffadc627b31519dd0e97
# Created 107 of 500 as 5e37ffadc627b31519dd0e98
# Created 108 of 500 as 5e37ffadc627b31519dd0e99
# Created 109 of 500 as 5e37ffadc627b31519dd0e9a
# Created 110 of 500 as 5e37ffadc627b31519dd0e9b
# Created 111 of 500 as 5e37ffadc627b31519dd0e9c
# Created 112 of 500 as 5e37ffadc627b31519dd0e9d
# Created 113 of 500 as 5e37ffadc627b31519dd0e9e
# Created 114 of 500 as 5e37ffadc627b31519dd0e9f
# Created 115 of 500 as 5e37ffadc627b31519dd0ea0
# Created 116 of 500 as 5e37ffadc627b31519dd0ea1
# Created 117 of 500 as 5e37ffadc627b31519dd0ea2
# Created 118 of 500 as 5e37ffadc627b31519dd0ea3
# Created 119 of 500 as 5e37ffadc627b31519dd0ea4
# Created 120 of 500 as 5e37ffadc627b31519dd0ea5
# Created 121 of 500 as 5e37ffadc627b31519dd0ea6
# Created 122 of 500 as 5e37ffadc627b31519dd0ea7
# Created 123 of 500 as 5e37ffadc627b31519dd0ea8
# Created 124 of 500 as 5e37ffadc627b31519dd0ea9
# Created 125 of 500 as 5e37ffadc627b31519dd0eaa
# Created 126 of 500 as 5e37ffadc627b31519dd0eab
# Created 127 of 500 as 5e37ffadc627b31519dd0eac
# Created 128 of 500 as 5e37ffadc627b31519dd0ead
# Created 129 of 500 as 5e37ffadc627b31519dd0eae
# Created 130 of 500 as 5e37ffadc627b31519dd0eaf
# Created 131 of 500 as 5e37ffadc627b31519dd0eb0
# Created 132 of 500 as 5e37ffadc627b31519dd0eb1
# Created 133 of 500 as 5e37ffadc627b31519dd0eb2
# Created 134 of 500 as 5e37ffadc627b31519dd0eb3
# Created 135 of 500 as 5e37ffadc627b31519dd0eb4
# Created 136 of 500 as 5e37ffadc627b31519dd0eb5
# Created 137 of 500 as 5e37ffadc627b31519dd0eb6
# Created 138 of 500 as 5e37ffadc627b31519dd0eb7
# Created 139 of 500 as 5e37ffadc627b31519dd0eb8
# Created 140 of 500 as 5e37ffadc627b31519dd0eb9
# Created 141 of 500 as 5e37ffadc627b31519dd0eba
# Created 142 of 500 as 5e37ffadc627b31519dd0ebb
# Created 143 of 500 as 5e37ffadc627b31519dd0ebc
# Created 144 of 500 as 5e37ffadc627b31519dd0ebd
# Created 145 of 500 as 5e37ffadc627b31519dd0ebe
# Created 146 of 500 as 5e37ffadc627b31519dd0ebf
# Created 147 of 500 as 5e37ffadc627b31519dd0ec0
# Created 148 of 500 as 5e37ffadc627b31519dd0ec1
# Created 149 of 500 as 5e37ffadc627b31519dd0ec2
# Created 150 of 500 as 5e37ffadc627b31519dd0ec3
# Created 151 of 500 as 5e37ffadc627b31519dd0ec4
# Created 152 of 500 as 5e37ffadc627b31519dd0ec5
# Created 153 of 500 as 5e37ffadc627b31519dd0ec6
# Created 154 of 500 as 5e37ffadc627b31519dd0ec7
# Created 155 of 500 as 5e37ffadc627b31519dd0ec8
# Created 156 of 500 as 5e37ffadc627b31519dd0ec9
# Created 157 of 500 as 5e37ffadc627b31519dd0eca
# Created 158 of 500 as 5e37ffadc627b31519dd0ecb
# Created 159 of 500 as 5e37ffadc627b31519dd0ecc
# Created 160 of 500 as 5e37ffadc627b31519dd0ecd
# Created 161 of 500 as 5e37ffadc627b31519dd0ece
# Created 162 of 500 as 5e37ffadc627b31519dd0ecf
# Created 163 of 500 as 5e37ffadc627b31519dd0ed0
# Created 164 of 500 as 5e37ffadc627b31519dd0ed1
# Created 165 of 500 as 5e37ffadc627b31519dd0ed2
# Created 166 of 500 as 5e37ffadc627b31519dd0ed3
# Created 167 of 500 as 5e37ffadc627b31519dd0ed4
# Created 168 of 500 as 5e37ffadc627b31519dd0ed5
# Created 169 of 500 as 5e37ffadc627b31519dd0ed6
# Created 170 of 500 as 5e37ffadc627b31519dd0ed7
# Created 171 of 500 as 5e37ffadc627b31519dd0ed8
# Created 172 of 500 as 5e37ffadc627b31519dd0ed9
# Created 173 of 500 as 5e37ffadc627b31519dd0eda
# Created 174 of 500 as 5e37ffadc627b31519dd0edb
# Created 175 of 500 as 5e37ffadc627b31519dd0edc
# Created 176 of 500 as 5e37ffadc627b31519dd0edd
# Created 177 of 500 as 5e37ffadc627b31519dd0ede
# Created 178 of 500 as 5e37ffadc627b31519dd0edf
# Created 179 of 500 as 5e37ffadc627b31519dd0ee0
# Created 180 of 500 as 5e37ffadc627b31519dd0ee1
# Created 181 of 500 as 5e37ffadc627b31519dd0ee2
# Created 182 of 500 as 5e37ffadc627b31519dd0ee3
# Created 183 of 500 as 5e37ffadc627b31519dd0ee4
# Created 184 of 500 as 5e37ffadc627b31519dd0ee5
# Created 185 of 500 as 5e37ffadc627b31519dd0ee6
# Created 186 of 500 as 5e37ffadc627b31519dd0ee7
# Created 187 of 500 as 5e37ffadc627b31519dd0ee8
# Created 188 of 500 as 5e37ffadc627b31519dd0ee9
# Created 189 of 500 as 5e37ffadc627b31519dd0eea
# Created 190 of 500 as 5e37ffadc627b31519dd0eeb
# Created 191 of 500 as 5e37ffadc627b31519dd0eec
# Created 192 of 500 as 5e37ffadc627b31519dd0eed
# Created 193 of 500 as 5e37ffadc627b31519dd0eee
# Created 194 of 500 as 5e37ffadc627b31519dd0eef
# Created 195 of 500 as 5e37ffadc627b31519dd0ef0
# Created 196 of 500 as 5e37ffadc627b31519dd0ef1
# Created 197 of 500 as 5e37ffadc627b31519dd0ef2
# Created 198 of 500 as 5e37ffadc627b31519dd0ef3
# Created 199 of 500 as 5e37ffadc627b31519dd0ef4
# Created 200 of 500 as 5e37ffadc627b31519dd0ef5
# Created 201 of 500 as 5e37ffadc627b31519dd0ef6
# Created 202 of 500 as 5e37ffadc627b31519dd0ef7
# Created 203 of 500 as 5e37ffadc627b31519dd0ef8
# Created 204 of 500 as 5e37ffadc627b31519dd0ef9
# Created 205 of 500 as 5e37ffadc627b31519dd0efa
# Created 206 of 500 as 5e37ffadc627b31519dd0efb
# Created 207 of 500 as 5e37ffadc627b31519dd0efc
# Created 208 of 500 as 5e37ffadc627b31519dd0efd
# Created 209 of 500 as 5e37ffadc627b31519dd0efe
# Created 210 of 500 as 5e37ffadc627b31519dd0eff
# Created 211 of 500 as 5e37ffadc627b31519dd0f00
# Created 212 of 500 as 5e37ffadc627b31519dd0f01
# Created 213 of 500 as 5e37ffadc627b31519dd0f02
# Created 214 of 500 as 5e37ffadc627b31519dd0f03
# Created 215 of 500 as 5e37ffadc627b31519dd0f04
# Created 216 of 500 as 5e37ffadc627b31519dd0f05
# Created 217 of 500 as 5e37ffadc627b31519dd0f06
# Created 218 of 500 as 5e37ffadc627b31519dd0f07
# Created 219 of 500 as 5e37ffadc627b31519dd0f08
# Created 220 of 500 as 5e37ffadc627b31519dd0f09
# Created 221 of 500 as 5e37ffadc627b31519dd0f0a
# Created 222 of 500 as 5e37ffadc627b31519dd0f0b
# Created 223 of 500 as 5e37ffadc627b31519dd0f0c
# Created 224 of 500 as 5e37ffadc627b31519dd0f0d
# Created 225 of 500 as 5e37ffadc627b31519dd0f0e
# Created 226 of 500 as 5e37ffadc627b31519dd0f0f
# Created 227 of 500 as 5e37ffadc627b31519dd0f10
# Created 228 of 500 as 5e37ffadc627b31519dd0f11
# Created 229 of 500 as 5e37ffadc627b31519dd0f12
# Created 230 of 500 as 5e37ffadc627b31519dd0f13
# Created 231 of 500 as 5e37ffadc627b31519dd0f14
# Created 232 of 500 as 5e37ffadc627b31519dd0f15
# Created 233 of 500 as 5e37ffadc627b31519dd0f16
# Created 234 of 500 as 5e37ffadc627b31519dd0f17
# Created 235 of 500 as 5e37ffadc627b31519dd0f18
# Created 236 of 500 as 5e37ffadc627b31519dd0f19
# Created 237 of 500 as 5e37ffadc627b31519dd0f1a
# Created 238 of 500 as 5e37ffadc627b31519dd0f1b
# Created 239 of 500 as 5e37ffadc627b31519dd0f1c
# Created 240 of 500 as 5e37ffadc627b31519dd0f1d
# Created 241 of 500 as 5e37ffadc627b31519dd0f1e
# Created 242 of 500 as 5e37ffadc627b31519dd0f1f
# Created 243 of 500 as 5e37ffadc627b31519dd0f20
# Created 244 of 500 as 5e37ffadc627b31519dd0f21
# Created 245 of 500 as 5e37ffadc627b31519dd0f22
# Created 246 of 500 as 5e37ffadc627b31519dd0f23
# Created 247 of 500 as 5e37ffadc627b31519dd0f24
# Created 248 of 500 as 5e37ffadc627b31519dd0f25
# Created 249 of 500 as 5e37ffadc627b31519dd0f26
# Created 250 of 500 as 5e37ffadc627b31519dd0f27
# Created 251 of 500 as 5e37ffadc627b31519dd0f28
# Created 252 of 500 as 5e37ffadc627b31519dd0f29
# Created 253 of 500 as 5e37ffadc627b31519dd0f2a
# Created 254 of 500 as 5e37ffadc627b31519dd0f2b
# Created 255 of 500 as 5e37ffadc627b31519dd0f2c
# Created 256 of 500 as 5e37ffadc627b31519dd0f2d
# Created 257 of 500 as 5e37ffadc627b31519dd0f2e
# Created 258 of 500 as 5e37ffadc627b31519dd0f2f
# Created 259 of 500 as 5e37ffadc627b31519dd0f30
# Created 260 of 500 as 5e37ffadc627b31519dd0f31
# Created 261 of 500 as 5e37ffadc627b31519dd0f32
# Created 262 of 500 as 5e37ffadc627b31519dd0f33
# Created 263 of 500 as 5e37ffadc627b31519dd0f34
# Created 264 of 500 as 5e37ffadc627b31519dd0f35
# Created 265 of 500 as 5e37ffadc627b31519dd0f36
# Created 266 of 500 as 5e37ffadc627b31519dd0f37
# Created 267 of 500 as 5e37ffadc627b31519dd0f38
# Created 268 of 500 as 5e37ffadc627b31519dd0f39
# Created 269 of 500 as 5e37ffadc627b31519dd0f3a
# Created 270 of 500 as 5e37ffadc627b31519dd0f3b
# Created 271 of 500 as 5e37ffadc627b31519dd0f3c
# Created 272 of 500 as 5e37ffadc627b31519dd0f3d
# Created 273 of 500 as 5e37ffadc627b31519dd0f3e
# Created 274 of 500 as 5e37ffadc627b31519dd0f3f
# Created 275 of 500 as 5e37ffadc627b31519dd0f40
# Created 276 of 500 as 5e37ffadc627b31519dd0f41
# Created 277 of 500 as 5e37ffadc627b31519dd0f42
# Created 278 of 500 as 5e37ffadc627b31519dd0f43
# Created 279 of 500 as 5e37ffadc627b31519dd0f44
# Created 280 of 500 as 5e37ffadc627b31519dd0f45
# Created 281 of 500 as 5e37ffadc627b31519dd0f46
# Created 282 of 500 as 5e37ffadc627b31519dd0f47
# Created 283 of 500 as 5e37ffadc627b31519dd0f48
# Created 284 of 500 as 5e37ffadc627b31519dd0f49
# Created 285 of 500 as 5e37ffadc627b31519dd0f4a
# Created 286 of 500 as 5e37ffadc627b31519dd0f4b
# Created 287 of 500 as 5e37ffadc627b31519dd0f4c
# Created 288 of 500 as 5e37ffadc627b31519dd0f4d
# Created 289 of 500 as 5e37ffadc627b31519dd0f4e
# Created 290 of 500 as 5e37ffadc627b31519dd0f4f
# Created 291 of 500 as 5e37ffadc627b31519dd0f50
# Created 292 of 500 as 5e37ffadc627b31519dd0f51
# Created 293 of 500 as 5e37ffadc627b31519dd0f52
# Created 294 of 500 as 5e37ffadc627b31519dd0f53
# Created 295 of 500 as 5e37ffadc627b31519dd0f54
# Created 296 of 500 as 5e37ffadc627b31519dd0f55
# Created 297 of 500 as 5e37ffadc627b31519dd0f56
# Created 298 of 500 as 5e37ffadc627b31519dd0f57
# Created 299 of 500 as 5e37ffadc627b31519dd0f58
# Created 300 of 500 as 5e37ffadc627b31519dd0f59
# Created 301 of 500 as 5e37ffadc627b31519dd0f5a
# Created 302 of 500 as 5e37ffadc627b31519dd0f5b
# Created 303 of 500 as 5e37ffadc627b31519dd0f5c
# Created 304 of 500 as 5e37ffadc627b31519dd0f5d
# Created 305 of 500 as 5e37ffadc627b31519dd0f5e
# Created 306 of 500 as 5e37ffadc627b31519dd0f5f
# Created 307 of 500 as 5e37ffadc627b31519dd0f60
# Created 308 of 500 as 5e37ffadc627b31519dd0f61
# Created 309 of 500 as 5e37ffadc627b31519dd0f62
# Created 310 of 500 as 5e37ffadc627b31519dd0f63
# Created 311 of 500 as 5e37ffadc627b31519dd0f64
# Created 312 of 500 as 5e37ffadc627b31519dd0f65
# Created 313 of 500 as 5e37ffadc627b31519dd0f66
# Created 314 of 500 as 5e37ffadc627b31519dd0f67
# Created 315 of 500 as 5e37ffadc627b31519dd0f68
# Created 316 of 500 as 5e37ffadc627b31519dd0f69
# Created 317 of 500 as 5e37ffadc627b31519dd0f6a
# Created 318 of 500 as 5e37ffadc627b31519dd0f6b
# Created 319 of 500 as 5e37ffadc627b31519dd0f6c
# Created 320 of 500 as 5e37ffadc627b31519dd0f6d
# Created 321 of 500 as 5e37ffadc627b31519dd0f6e
# Created 322 of 500 as 5e37ffadc627b31519dd0f6f
# Created 323 of 500 as 5e37ffadc627b31519dd0f70
# Created 324 of 500 as 5e37ffadc627b31519dd0f71
# Created 325 of 500 as 5e37ffadc627b31519dd0f72
# Created 326 of 500 as 5e37ffadc627b31519dd0f73
# Created 327 of 500 as 5e37ffadc627b31519dd0f74
# Created 328 of 500 as 5e37ffadc627b31519dd0f75
# Created 329 of 500 as 5e37ffadc627b31519dd0f76
# Created 330 of 500 as 5e37ffadc627b31519dd0f77
# Created 331 of 500 as 5e37ffadc627b31519dd0f78
# Created 332 of 500 as 5e37ffadc627b31519dd0f79
# Created 333 of 500 as 5e37ffadc627b31519dd0f7a
# Created 334 of 500 as 5e37ffadc627b31519dd0f7b
# Created 335 of 500 as 5e37ffadc627b31519dd0f7c
# Created 336 of 500 as 5e37ffadc627b31519dd0f7d
# Created 337 of 500 as 5e37ffadc627b31519dd0f7e
# Created 338 of 500 as 5e37ffadc627b31519dd0f7f
# Created 339 of 500 as 5e37ffadc627b31519dd0f80
# Created 340 of 500 as 5e37ffadc627b31519dd0f81
# Created 341 of 500 as 5e37ffadc627b31519dd0f82
# Created 342 of 500 as 5e37ffadc627b31519dd0f83
# Created 343 of 500 as 5e37ffadc627b31519dd0f84
# Created 344 of 500 as 5e37ffadc627b31519dd0f85
# Created 345 of 500 as 5e37ffadc627b31519dd0f86
# Created 346 of 500 as 5e37ffadc627b31519dd0f87
# Created 347 of 500 as 5e37ffadc627b31519dd0f88
# Created 348 of 500 as 5e37ffadc627b31519dd0f89
# Created 349 of 500 as 5e37ffadc627b31519dd0f8a
# Created 350 of 500 as 5e37ffadc627b31519dd0f8b
# Created 351 of 500 as 5e37ffadc627b31519dd0f8c
# Created 352 of 500 as 5e37ffadc627b31519dd0f8d
# Created 353 of 500 as 5e37ffadc627b31519dd0f8e
# Created 354 of 500 as 5e37ffadc627b31519dd0f8f
# Created 355 of 500 as 5e37ffadc627b31519dd0f90
# Created 356 of 500 as 5e37ffadc627b31519dd0f91
# Created 357 of 500 as 5e37ffadc627b31519dd0f92
# Created 358 of 500 as 5e37ffadc627b31519dd0f93
# Created 359 of 500 as 5e37ffadc627b31519dd0f94
# Created 360 of 500 as 5e37ffadc627b31519dd0f95
# Created 361 of 500 as 5e37ffadc627b31519dd0f96
# Created 362 of 500 as 5e37ffadc627b31519dd0f97
# Created 363 of 500 as 5e37ffadc627b31519dd0f98
# Created 364 of 500 as 5e37ffadc627b31519dd0f99
# Created 365 of 500 as 5e37ffadc627b31519dd0f9a
# Created 366 of 500 as 5e37ffadc627b31519dd0f9b
# Created 367 of 500 as 5e37ffadc627b31519dd0f9c
# Created 368 of 500 as 5e37ffadc627b31519dd0f9d
# Created 369 of 500 as 5e37ffadc627b31519dd0f9e
# Created 370 of 500 as 5e37ffadc627b31519dd0f9f
# Created 371 of 500 as 5e37ffadc627b31519dd0fa0
# Created 372 of 500 as 5e37ffadc627b31519dd0fa1
# Created 373 of 500 as 5e37ffadc627b31519dd0fa2
# Created 374 of 500 as 5e37ffadc627b31519dd0fa3
# Created 375 of 500 as 5e37ffadc627b31519dd0fa4
# Created 376 of 500 as 5e37ffadc627b31519dd0fa5
# Created 377 of 500 as 5e37ffadc627b31519dd0fa6
# Created 378 of 500 as 5e37ffadc627b31519dd0fa7
# Created 379 of 500 as 5e37ffadc627b31519dd0fa8
# Created 380 of 500 as 5e37ffadc627b31519dd0fa9
# Created 381 of 500 as 5e37ffadc627b31519dd0faa
# Created 382 of 500 as 5e37ffadc627b31519dd0fab
# Created 383 of 500 as 5e37ffadc627b31519dd0fac
# Created 384 of 500 as 5e37ffadc627b31519dd0fad
# Created 385 of 500 as 5e37ffadc627b31519dd0fae
# Created 386 of 500 as 5e37ffadc627b31519dd0faf
# Created 387 of 500 as 5e37ffadc627b31519dd0fb0
# Created 388 of 500 as 5e37ffadc627b31519dd0fb1
# Created 389 of 500 as 5e37ffadc627b31519dd0fb2
# Created 390 of 500 as 5e37ffadc627b31519dd0fb3
# Created 391 of 500 as 5e37ffadc627b31519dd0fb4
# Created 392 of 500 as 5e37ffadc627b31519dd0fb5
# Created 393 of 500 as 5e37ffadc627b31519dd0fb6
# Created 394 of 500 as 5e37ffadc627b31519dd0fb7
# Created 395 of 500 as 5e37ffadc627b31519dd0fb8
# Created 396 of 500 as 5e37ffadc627b31519dd0fb9
# Created 397 of 500 as 5e37ffadc627b31519dd0fba
# Created 398 of 500 as 5e37ffadc627b31519dd0fbb
# Created 399 of 500 as 5e37ffadc627b31519dd0fbc
# Created 400 of 500 as 5e37ffadc627b31519dd0fbd
# Created 401 of 500 as 5e37ffadc627b31519dd0fbe
# Created 402 of 500 as 5e37ffadc627b31519dd0fbf
# Created 403 of 500 as 5e37ffadc627b31519dd0fc0
# Created 404 of 500 as 5e37ffadc627b31519dd0fc1
# Created 405 of 500 as 5e37ffadc627b31519dd0fc2
# Created 406 of 500 as 5e37ffadc627b31519dd0fc3
# Created 407 of 500 as 5e37ffadc627b31519dd0fc4
# Created 408 of 500 as 5e37ffadc627b31519dd0fc5
# Created 409 of 500 as 5e37ffadc627b31519dd0fc6
# Created 410 of 500 as 5e37ffadc627b31519dd0fc7
# Created 411 of 500 as 5e37ffadc627b31519dd0fc8
# Created 412 of 500 as 5e37ffadc627b31519dd0fc9
# Created 413 of 500 as 5e37ffadc627b31519dd0fca
# Created 414 of 500 as 5e37ffadc627b31519dd0fcb
# Created 415 of 500 as 5e37ffadc627b31519dd0fcc
# Created 416 of 500 as 5e37ffadc627b31519dd0fcd
# Created 417 of 500 as 5e37ffadc627b31519dd0fce
# Created 418 of 500 as 5e37ffadc627b31519dd0fcf
# Created 419 of 500 as 5e37ffadc627b31519dd0fd0
# Created 420 of 500 as 5e37ffadc627b31519dd0fd1
# Created 421 of 500 as 5e37ffadc627b31519dd0fd2
# Created 422 of 500 as 5e37ffadc627b31519dd0fd3
# Created 423 of 500 as 5e37ffadc627b31519dd0fd4
# Created 424 of 500 as 5e37ffadc627b31519dd0fd5
# Created 425 of 500 as 5e37ffadc627b31519dd0fd6
# Created 426 of 500 as 5e37ffadc627b31519dd0fd7
# Created 427 of 500 as 5e37ffadc627b31519dd0fd8
# Created 428 of 500 as 5e37ffadc627b31519dd0fd9
# Created 429 of 500 as 5e37ffadc627b31519dd0fda
# Created 430 of 500 as 5e37ffadc627b31519dd0fdb
# Created 431 of 500 as 5e37ffadc627b31519dd0fdc
# Created 432 of 500 as 5e37ffadc627b31519dd0fdd
# Created 433 of 500 as 5e37ffadc627b31519dd0fde
# Created 434 of 500 as 5e37ffadc627b31519dd0fdf
# Created 435 of 500 as 5e37ffadc627b31519dd0fe0
# Created 436 of 500 as 5e37ffadc627b31519dd0fe1
# Created 437 of 500 as 5e37ffadc627b31519dd0fe2
# Created 438 of 500 as 5e37ffadc627b31519dd0fe3
# Created 439 of 500 as 5e37ffadc627b31519dd0fe4
# Created 440 of 500 as 5e37ffadc627b31519dd0fe5
# Created 441 of 500 as 5e37ffadc627b31519dd0fe6
# Created 442 of 500 as 5e37ffadc627b31519dd0fe7
# Created 443 of 500 as 5e37ffadc627b31519dd0fe8
# Created 444 of 500 as 5e37ffadc627b31519dd0fe9
# Created 445 of 500 as 5e37ffadc627b31519dd0fea
# Created 446 of 500 as 5e37ffadc627b31519dd0feb
# Created 447 of 500 as 5e37ffadc627b31519dd0fec
# Created 448 of 500 as 5e37ffadc627b31519dd0fed
# Created 449 of 500 as 5e37ffadc627b31519dd0fee
# Created 450 of 500 as 5e37ffadc627b31519dd0fef
# Created 451 of 500 as 5e37ffadc627b31519dd0ff0
# Created 452 of 500 as 5e37ffadc627b31519dd0ff1
# Created 453 of 500 as 5e37ffadc627b31519dd0ff2
# Created 454 of 500 as 5e37ffadc627b31519dd0ff3
# Created 455 of 500 as 5e37ffadc627b31519dd0ff4
# Created 456 of 500 as 5e37ffadc627b31519dd0ff5
# Created 457 of 500 as 5e37ffadc627b31519dd0ff6
# Created 458 of 500 as 5e37ffadc627b31519dd0ff7
# Created 459 of 500 as 5e37ffadc627b31519dd0ff8
# Created 460 of 500 as 5e37ffadc627b31519dd0ff9
# Created 461 of 500 as 5e37ffadc627b31519dd0ffa
# Created 462 of 500 as 5e37ffadc627b31519dd0ffb
# Created 463 of 500 as 5e37ffadc627b31519dd0ffc
# Created 464 of 500 as 5e37ffadc627b31519dd0ffd
# Created 465 of 500 as 5e37ffadc627b31519dd0ffe
# Created 466 of 500 as 5e37ffadc627b31519dd0fff
# Created 467 of 500 as 5e37ffadc627b31519dd1000
# Created 468 of 500 as 5e37ffadc627b31519dd1001
# Created 469 of 500 as 5e37ffadc627b31519dd1002
# Created 470 of 500 as 5e37ffadc627b31519dd1003
# Created 471 of 500 as 5e37ffadc627b31519dd1004
# Created 472 of 500 as 5e37ffadc627b31519dd1005
# Created 473 of 500 as 5e37ffadc627b31519dd1006
# Created 474 of 500 as 5e37ffadc627b31519dd1007
# Created 475 of 500 as 5e37ffadc627b31519dd1008
# Created 476 of 500 as 5e37ffadc627b31519dd1009
# Created 477 of 500 as 5e37ffadc627b31519dd100a
# Created 478 of 500 as 5e37ffadc627b31519dd100b
# Created 479 of 500 as 5e37ffadc627b31519dd100c
# Created 480 of 500 as 5e37ffadc627b31519dd100d
# Created 481 of 500 as 5e37ffadc627b31519dd100e
# Created 482 of 500 as 5e37ffadc627b31519dd100f
# Created 483 of 500 as 5e37ffadc627b31519dd1010
# Created 484 of 500 as 5e37ffadc627b31519dd1011
# Created 485 of 500 as 5e37ffadc627b31519dd1012
# Created 486 of 500 as 5e37ffadc627b31519dd1013
# Created 487 of 500 as 5e37ffadc627b31519dd1014
# Created 488 of 500 as 5e37ffadc627b31519dd1015
# Created 489 of 500 as 5e37ffadc627b31519dd1016
# Created 490 of 500 as 5e37ffadc627b31519dd1017
# Created 491 of 500 as 5e37ffadc627b31519dd1018
# Created 492 of 500 as 5e37ffadc627b31519dd1019
# Created 493 of 500 as 5e37ffadc627b31519dd101a
# Created 494 of 500 as 5e37ffadc627b31519dd101b
# Created 495 of 500 as 5e37ffadc627b31519dd101c
# Created 496 of 500 as 5e37ffadc627b31519dd101d
# Created 497 of 500 as 5e37ffadc627b31519dd101e
# Created 498 of 500 as 5e37ffadc627b31519dd101f
# Created 499 of 500 as 5e37ffadc627b31519dd1020
# Created 500 of 500 as 5e37ffadc627b31519dd1021
# finished creating 500 business reviews
